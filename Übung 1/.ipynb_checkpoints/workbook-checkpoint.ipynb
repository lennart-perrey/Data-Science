# %% [markdown]
# # Workbook
#
# Use this notebook to complete the exercises throughout the workshop.
#
# #### Table of Contents
# - [Section 1 &ndash; Getting Started with Pandas](#Section-1)
# - [Section 2 &ndash; Data Wrangling](#Section-2)
# - [Section 3 &ndash; Data Visualization](#Section-3)
#
# ---
#
# ### Section 1
#
# #### Exercise 1.1
# ##### Create a DataFrame by reading in the `2019_Yellow_Taxi_Trip_Data.csv` file. Examine the first 5 rows.

# %%
import pandas as pd
csv_file_path = '2019_Yellow_Taxi_Trip_Data.csv'
df = pd.read_csv(csv_file_path)
print(df.head())
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# 1            11            26             1         10.5    1.0      0.5
# 2           163           162             1          9.5    1.0      0.5
# 3           170           163             1         13.0    1.0      0.5
# 4           163           236             1         10.5    1.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        7.98          6.12                    0.3         47.90
# 1        0.00          0.00                    0.3         12.30
# 2        2.00          0.00                    0.3         15.80
# 3        4.32          0.00                    0.3         21.62
# 4        0.50          0.00                    0.3         15.30
#
#    congestion_surcharge
# 0                   2.5
# 1                   0.0
# 2                   2.5
# 3                   2.5
# 4                   2.5

# %% [markdown]
# #### Exercise 1.2
# ##### Find the dimensions (number of rows and number of columns) in the data.

# %%
num_rows, num_columns = df.shape
print(f"Number of Rows: {num_rows}")
print(f"Number of Columns: {num_columns}")
# Out:
# Number of Rows: 10000
# Number of Columns: 18

# %% [markdown]
# #### Exercise 1.3
# ##### Using the data in the `2019_Yellow_Taxi_Trip_Data.csv` file, calculate summary statistics for the `fare_amount`, `tip_amount`, `tolls_amount`, and `total_amount` columns.

# %%
summary_stats = df[["fare_amount", "tip_amount", "tolls_amount", "total_amount"]].describe()
print(summary_stats)
# Out:
#         fare_amount    tip_amount  tolls_amount  total_amount
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean      15.106313      2.634494      0.623447     22.564659
# std       13.954762      3.409800      6.437507     19.209255
# min      -52.000000      0.000000     -6.120000    -65.920000
# 25%        7.000000      0.000000      0.000000     12.375000
# 50%       10.000000      2.000000      0.000000     16.300000
# 75%       16.000000      3.250000      0.000000     22.880000
# max      176.000000     43.000000    612.000000    671.800000

# %% [markdown]
# #### Exercise 1.4
# ##### Isolate the `fare_amount`, `tip_amount`, `tolls_amount`, and `total_amount` for the longest trip by distance (`trip_distance`).

# %%
max_distance_index = df['trip_distance'].idxmax()
longest_trip_data = df.loc[max_distance_index, ["fare_amount", "tip_amount", "tolls_amount", "total_amount"]]
print("Isolated values for the longest trip by distance:")
print(longest_trip_data)
# Out:
# Isolated values for the longest trip by distance:
# fare_amount      176.0
# tip_amount       18.29
# tolls_amount      6.12
# total_amount    201.21
# Name: 8338, dtype: object

# %% [markdown]
# ---
#
# ### Section 2
#
# #### Exercise 2.1
# ##### Read in the meteorite data from the `Meteorite_Landings.csv` file, rename the `mass (g)` column to `mass`, and drop all the latitude and longitude columns. Sort the result by mass in descending order.

# %%
csv_file_path = 'Meteorite_Landings.csv'
meteorite_df = pd.read_csv(csv_file_path)
meteorite_df = meteorite_df.rename(columns={'mass (g)': 'mass'})
meteorite_df = meteorite_df.drop(['reclat', 'reclong'], axis=1)
meteorite_df = meteorite_df.sort_values(by='mass', ascending=False)
meteorite_df.head()
# Out:
#                   name     id nametype      recclass        mass   fall  \
# 16392             Hoba  11890    Valid     Iron, IVB  60000000.0  Found
# 5373         Cape York   5262    Valid   Iron, IIIAB  58200000.0  Found
# 5365   Campo del Cielo   5247    Valid  Iron, IAB-MG  50000000.0  Found
# 5370     Canyon Diablo   5257    Valid  Iron, IAB-MG  30000000.0  Found
# 3455           Armanty   2335    Valid    Iron, IIIE  28000000.0  Found
#
#                          year             GeoLocation
# 16392  01/01/1920 12:00:00 AM   (-19.58333, 17.91667)
# 5373   01/01/1818 12:00:00 AM   (76.13333, -64.93333)
# 5365   12/22/1575 12:00:00 AM  (-27.46667, -60.58333)
# 5370   01/01/1891 12:00:00 AM     (35.05, -111.03333)
# 3455   01/01/1898 12:00:00 AM            (47.0, 88.0)

# %% [markdown]
# #### Exercise 2.2
# ##### Using the meteorite data from the `Meteorite_Landings.csv` file, update the `year` column to only contain the year, convert it to a numeric data type, and create a new column indicating whether the meteorite was observed falling before 1970. Set the index to the `id` column and extract all the rows with IDs between 10,036 and 10,040 (inclusive) with `loc[]`.
#
# ###### **Hint 1**: Use `year.str.slice()` to grab a substring.
#
# ###### **Hint 2**: Make sure to sort the index before using `loc[]` to select the range.
#
# ###### **Bonus**: There's a data entry error in the `year` column. Can you find it? (Don't spend too much time on this.)

# %%
meteorite_df.head()
meteorite_df['year'] = meteorite_df['year'].astype(str).str[:4]
meteorite_df['year'] = pd.to_numeric(meteorite_df['year'], errors='coerce')
meteorite_df['fall_before_1970'] = meteorite_df['year'] < 1970
meteorite_df.set_index('id', inplace=True)
meteorite_df.sort_index(inplace=True)
selected_rows = meteorite_df.loc[10036:10040]
print(selected_rows)
meteorite_df.head()
# Out:
#             name nametype         recclass      mass   fall  year  \
# id
# 10036     Enigma    Valid               H4      94.0  Found   NaN
# 10037       Enon    Valid  Iron, ungrouped     763.0  Found   NaN
# 10038      Enshi    Valid               H5    8000.0   Fell   NaN
# 10039  Ensisheim    Valid              LL6  127000.0   Fell   NaN
#
#                  GeoLocation  fall_before_1970
# id
# 10036  (31.33333, -82.31667)             False
# 10037     (39.86667, -83.95)             False
# 10038          (30.3, 109.5)             False
# 10039       (47.86667, 7.35)             False
#       name nametype recclass      mass   fall  year           GeoLocation  \
# id
# 1   Aachen    Valid       L5      21.0   Fell   NaN     (50.775, 6.08333)
# 2   Aarhus    Valid       H6     720.0   Fell   NaN  (56.18333, 10.23333)
# 4    Abajo    Valid       H5     331.0  Found   NaN    (26.8, -105.41667)
# 5   Abbott    Valid     H3-6   21100.0  Found   NaN    (36.3, -104.28333)
# 6     Abee    Valid      EH4  107000.0   Fell   NaN    (54.21667, -113.0)
#
#     fall_before_1970
# id
# 1              False
# 2              False
# 4              False
# 5              False
# 6              False

# %% [markdown]
# #### Exercise 2.3
# ##### Using the meteorite data from the `Meteorite_Landings.csv` file, create a pivot table that shows both the number of meteorites and the 95th percentile of meteorite mass for those that were found versus observed falling per year from 2005 through 2009 (inclusive). Hint: Be sure to convert the `year` column to a number as we did in the previous exercise.

# %%
meteorite_data = pd.read_csv('Meteorite_Landings.csv')
# Convert the 'year' column to numeric, handling errors by coercing to NaN
meteorite_data['year'] = pd.to_numeric(meteorite_data['year'].astype(str).str[:4], errors='coerce')
print(meteorite_data['year'])
# Filter data for the years 2005 through 2009 (inclusive)
filtered_data = meteorite_data[(meteorite_data['year'] >= 2005) & (meteorite_data['year'] <= 2009)]
print(filtered_data.head())
# Out:
# Empty DataFrame
# Columns: [name, id, nametype, recclass, mass (g), fall, year, reclat, reclong, GeoLocation]
# Index: []

# %% [markdown]
# #### Exercise 2.4
# ##### Using the meteorite data from the `Meteorite_Landings.csv` file, compare summary statistics of the mass column for the meteorites that were found versus observed falling.

# %% [markdown]
# #### Exercise 2.5
# ##### Using the taxi trip data in the `2019_Yellow_Taxi_Trip_Data.csv` file, resample the data to an hourly frequency based on the dropoff time. Calculate the total `trip_distance`, `fare_amount`, `tolls_amount`, and `tip_amount`, then find the 5 hours with the most tips.

# %% [markdown]
# ---
#
# ### Section 3
#
# #### Exercise 3.1
# ##### Using the TSA traveler throughput data in the `tsa_melted_holiday_travel.csv` file, create box plots for traveler throughput for each year in the data. Hint: Pass `kind='box'` into the `plot()` method to generate box plots.

# %%
file_path = 'tsa_melted_holiday_travel.csv' 
df = pd.read_csv(file_path)
df.boxplot(column='travelers', by='year')
plt.show()

# %% [markdown]
# #### Exercise 3.2
# ##### Using the TSA traveler throughput data in the `tsa_melted_holiday_travel.csv` file, create a heatmap that shows the 2019 TSA median traveler throughput by day of week and month.

# %%
df['date'] = pd.to_datetime(df['date'])
df_2019 = df[df['date'].dt.year == 2019].copy() #copy(), so we dont get a warning here
df_2019['day'] = df_2019['date'].dt.day_name()
df_2019['month'] = df_2019['date'].dt.month_name()
pivot_table = df_2019.pivot_table(values='travelers', index='day', columns='month', aggfunc='median')
months_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
pivot_table = pivot_table.reindex(columns=months_order)
pivot_table.style.background_gradient()
# Out:
# <style type="text/css">
# #T_863a7_row0_col0, #T_863a7_row4_col1, #T_863a7_row5_col2, #T_863a7_row5_col3, #T_863a7_row5_col4, #T_863a7_row6_col5, #T_863a7_row6_col6, #T_863a7_row6_col7, #T_863a7_row6_col8, #T_863a7_row6_col9, #T_863a7_row6_col10, #T_863a7_row6_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_863a7_row0_col1 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_863a7_row0_col2 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_863a7_row0_col3 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_863a7_row0_col4, #T_863a7_row2_col11 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_863a7_row0_col5 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_863a7_row0_col6, #T_863a7_row1_col3 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_863a7_row0_col7, #T_863a7_row6_col4 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_863a7_row0_col8 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_863a7_row0_col9, #T_863a7_row5_col6 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_863a7_row0_col10, #T_863a7_row2_col8, #T_863a7_row5_col10 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_863a7_row0_col11, #T_863a7_row2_col7 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_863a7_row1_col0 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_863a7_row1_col1 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_863a7_row1_col2, #T_863a7_row5_col7 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_863a7_row1_col4 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_863a7_row1_col5, #T_863a7_row3_col3 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_863a7_row1_col6 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_863a7_row1_col7 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_863a7_row1_col8 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_863a7_row1_col9 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_863a7_row1_col10 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_863a7_row1_col11 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_863a7_row2_col0, #T_863a7_row2_col2, #T_863a7_row3_col11, #T_863a7_row4_col4, #T_863a7_row4_col5, #T_863a7_row4_col6, #T_863a7_row4_col7, #T_863a7_row4_col8, #T_863a7_row4_col9, #T_863a7_row4_col10, #T_863a7_row5_col1, #T_863a7_row6_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_863a7_row2_col1 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_863a7_row2_col3 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_863a7_row2_col4 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_863a7_row2_col5 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_863a7_row2_col6 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_863a7_row2_col9 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_863a7_row2_col10 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_863a7_row3_col0 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_863a7_row3_col1 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_863a7_row3_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_863a7_row3_col4 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_863a7_row3_col5 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_863a7_row3_col6 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_863a7_row3_col7, #T_863a7_row3_col9 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_863a7_row3_col8 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_863a7_row3_col10 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_863a7_row4_col0 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_863a7_row4_col2 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_863a7_row4_col3 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_863a7_row4_col11 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_863a7_row5_col0 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_863a7_row5_col5 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_863a7_row5_col8 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_863a7_row5_col9 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_863a7_row5_col11 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_863a7_row6_col0 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_863a7_row6_col1 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_863a7_row6_col2 {
#   background-color: #e0dded;
#   color: #000000;
# }
# </style>
# <table id="T_863a7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th id="T_863a7_level0_col0" class="col_heading level0 col0" >January</th>
#       <th id="T_863a7_level0_col1" class="col_heading level0 col1" >February</th>
#       <th id="T_863a7_level0_col2" class="col_heading level0 col2" >March</th>
#       <th id="T_863a7_level0_col3" class="col_heading level0 col3" >April</th>
#       <th id="T_863a7_level0_col4" class="col_heading level0 col4" >May</th>
#       <th id="T_863a7_level0_col5" class="col_heading level0 col5" >June</th>
#       <th id="T_863a7_level0_col6" class="col_heading level0 col6" >July</th>
#       <th id="T_863a7_level0_col7" class="col_heading level0 col7" >August</th>
#       <th id="T_863a7_level0_col8" class="col_heading level0 col8" >September</th>
#       <th id="T_863a7_level0_col9" class="col_heading level0 col9" >October</th>
#       <th id="T_863a7_level0_col10" class="col_heading level0 col10" >November</th>
#       <th id="T_863a7_level0_col11" class="col_heading level0 col11" >December</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_863a7_level0_row0" class="row_heading level0 row0" >Friday</th>
#       <td id="T_863a7_row0_col0" class="data row0 col0" >2101692.500000</td>
#       <td id="T_863a7_row0_col1" class="data row0 col1" >2106456.500000</td>
#       <td id="T_863a7_row0_col2" class="data row0 col2" >2378673.000000</td>
#       <td id="T_863a7_row0_col3" class="data row0 col3" >2448675.000000</td>
#       <td id="T_863a7_row0_col4" class="data row0 col4" >2512315.000000</td>
#       <td id="T_863a7_row0_col5" class="data row0 col5" >2655971.500000</td>
#       <td id="T_863a7_row0_col6" class="data row0 col6" >2714039.000000</td>
#       <td id="T_863a7_row0_col7" class="data row0 col7" >2584444.000000</td>
#       <td id="T_863a7_row0_col8" class="data row0 col8" >2468865.000000</td>
#       <td id="T_863a7_row0_col9" class="data row0 col9" >2548725.500000</td>
#       <td id="T_863a7_row0_col10" class="data row0 col10" >2396681.000000</td>
#       <td id="T_863a7_row0_col11" class="data row0 col11" >2409823.500000</td>
#     </tr>
#     <tr>
#       <th id="T_863a7_level0_row1" class="row_heading level0 row1" >Monday</th>
#       <td id="T_863a7_row1_col0" class="data row1 col0" >1965342.500000</td>
#       <td id="T_863a7_row1_col1" class="data row1 col1" >2108074.500000</td>
#       <td id="T_863a7_row1_col2" class="data row1 col2" >2495543.000000</td>
#       <td id="T_863a7_row1_col3" class="data row1 col3" >2499461.000000</td>
#       <td id="T_863a7_row1_col4" class="data row1 col4" >2513732.500000</td>
#       <td id="T_863a7_row1_col5" class="data row1 col5" >2530726.500000</td>
#       <td id="T_863a7_row1_col6" class="data row1 col6" >2542365.000000</td>
#       <td id="T_863a7_row1_col7" class="data row1 col7" >2349372.000000</td>
#       <td id="T_863a7_row1_col8" class="data row1 col8" >2082179.000000</td>
#       <td id="T_863a7_row1_col9" class="data row1 col9" >2230216.000000</td>
#       <td id="T_863a7_row1_col10" class="data row1 col10" >2110044.500000</td>
#       <td id="T_863a7_row1_col11" class="data row1 c

# %% [markdown]
# #### Exercise 3.3
# ##### Annotate the medians in the box plot from *[Exercise 3.1](#Exercise-3.1)*. Hint: The `x` coordinates will be 1, 2, and 3 for 2019, 2020, and 2021, respectively. Alternatively, to avoid hardcoding values, you can use the `Axes.get_xticklabels()` method, in which case you should look at the [documentation](https://matplotlib.org/stable/api/text_api.html) for the `Text` class.

# %%
boxplot = df.boxplot(column='travelers', by='year')
medians = df.groupby('year')['travelers'].median()
x_positions = [i + 1 for i in range(len(df['year'].unique()))]

for x, median in zip(x_positions, medians):
    label = boxplot.get_xticklabels()[x - 1]
    boxplot.annotate(str(median), xy=(x, median))

plt.show()
